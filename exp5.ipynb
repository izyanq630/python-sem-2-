# %% [markdown]
# <a href="https://colab.research.google.com/github/izyanq630/python-sem-2-/blob/main/exp5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
